# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From c:\Users\rajes\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
### sentences

sent=[
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'i am a good boy',
    'i am a good developer',
    'understand the meaning of words',
    'your videos are good'
]

# %%
## define the vocabulary size
voc_size=10000

# %%
### One hot representation
one_hot_repr=[one_hot(words,voc_size) for words in sent]
one_hot_repr
# Out:
# [[5261, 2610, 7255, 5209],
#  [5261, 2610, 7255, 7675],
#  [5261, 1998, 7255, 9113],
#  [2819, 3986, 4088, 18, 7478],
#  [2819, 3986, 4088, 18, 5041],
#  [5411, 5261, 5517, 7255, 509],
#  [7901, 1541, 8861, 18]]

# %%
## word Embedding Representation

from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 5261 2610 7255 5209]
#  [   0    0    0    0 5261 2610 7255 7675]
#  [   0    0    0    0 5261 1998 7255 9113]
#  [   0    0    0 2819 3986 4088   18 7478]
#  [   0    0    0 2819 3986 4088   18 5041]
#  [   0    0    0 5411 5261 5517 7255  509]
#  [   0    0    0    0 7901 1541 8861   18]]

# %%
## Feature representation
dim=10

# %%
## create model

model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 155ms/step
# array([[[ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.01383973,  0.04544861, -0.01895607, -0.01044328,
#          -0.01875314,  0.01859024,  0.00737593, -0.01123857,
#           0.03578499,  0.02077464],
#         [-0.03501792,  0.01729376,  0.03904418,  0.04077554,
#           0.00227157, -0.03203354, -0.0316484 , -0.03302421,
#           0.02911455, -0.02217838],
#         [ 0.01972734, -0.04935158, -0.02568839, -0.0477609 ,
#          -0.00703432, -0.01133585,  0.03427711, -0.03507178,
#           0.04701957, -0.03857826],
#         [-0.03052192,  0.01074275,  0.02734255,  0.04745148,
#          -0.03371608,  0.00233201,  0.00951051,  0.04741924,
#           0.01109763, -0.02909858]],
#
#        [[ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.01383973,  0.04544861, -0.01895607, -0.01044328,
#          -0.01875314,  0.01859024,  0.00737593, -0.01123857,
#           0.03578499,  0.02077464],
#         [-0.03501792,  0.01729376,  0.03904418,  0.04077554,
#           0.00227157, -0.03203354, -0.0316484 , -0.03302421,
#           0.02911455, -0.02217838],
#         [ 0.01972734, -0.04935158, -0.02568839, -0.0477609 ,
#          -0.00703432, -0.01133585,  0.03427711, -0.03507178,
#           0.04701957, -0.03857826],
#         [-0.01902365,  0.00569152,  0.04527297,  0.04740477,
#           0.01013551,  0.02784489, -0.00667664, -0.04225507,
#          -0.04410721, -0.00659709]],
#
#        [[ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.01383973,  0.04544861, -0.01895607, -0.01044328,
#          -0.01875314,  0.01859024,  0.00737593, -0.01123857,
#           0.03578499,  0.02077464],
#         [ 0.01141055, -0.02792405,  0.04654405,  0.00460345,
#           0.03328756, -0.02101126,  0.01139505,  0.03194794,
#           0.01435537,  0.0025664 ],
#         [ 0.01972734, -0.04935158, -0.02568839, -0.0477609 ,
#          -0.00703432, -0.01133585,  0.03427711, -0.03507178,
#           0.04701957, -0.03857826],
#         [ 0.00377345, -0.03916038,  0.01052336, -0.04548477,
#          -0.04675303,  0.01117013,  0.02202407, -0.03564013,
#          -0.0112593 ,  0.0074091 ]],
#
#        [[ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.00593008,  0.04915505,  0.03766889,  0.02129385,
#          -0.02187699,  0.01402782, -0.00664871,  0.04976923,
#          -0.02319762, -0.02726418],
#         [-0.04114704,  0.04699271,  0.0082909 ,  0.01694607,
#           0.03013258, -0.01821059,  0.02820588, -0.04028363,
#          -0.04412591, -0.02099909],
#         [ 0.0390153 ,  0.02110692, -0.02718752,  0.03514593,
#           0.04648731, -0.01905041, -0.03757731,  0.02286741,
#           0.01968277,  0.00226916],
#         [-0.02447709, -0.01647984, -0.03584441,  0.01272103,
#           0.04182531,  0.00438714, -0.04530661, -0.00569409,
#           0.01763486,  0.0427967 ],
#         [ 0.01296176, -0.03428902, -0.03367565,  0.0315946 ,
#          -0.01778341, -0.0081841 , -0.01497812, -0.02802626,
#           0.03294697,  0.00614635]],
#
#        [[ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.00593008,  0.04915505,  0.03766889,  0.02129385,
#          -0.02187699,  0.01402782, -0.00664871,  0.04976923,
#          -0.02319762, -0.02726418],
#         [-0.04114704,  0.04699271,  0.0082909 ,  0.01694607,
#           0.03013258, -0.01821059,  0.02820588, -0.04028363,
#          -0.04412591, -0.02099909],
#         [ 0.0390153 ,  0.02110692, -0.02718752,  0.03514593,
#           0.04648731, -0.01905041, -0.03757731,  0.02286741,
#           0.01968277,  0.00226916],
#         [-0.02447709, -0.01647984, -0.03584441,  0.01272103,
#           0.04182531,  0.00438714, -0.04530661, -0.00569409,
#           0.01763486,  0.0427967 ],
#         [ 0.02298942,  0.00166804, -0.00082693,  0.04835996,
#           0.02130587, -0.03246486, -0.00869612,  0.00340556,
#           0.01123303, -0.02482214]],
#
#        [[ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.01240446, -0.04220139,  0.02987284, -0.00052222,
#           0.04395993, -0.02563908, -0.02536722, -0.02464728,
#           0.00689839,  0.0089777 ],
#         [ 0.01383973,  0.04544861, -0.01895607, -0.01044328,
#          -0.01875314,  0.01859024,  0.00737593, -0.01123857,
#           0.03578499,  0.02077464],
#         [ 0.04661981,  0.02149167,  0.02275529,  0.04091031,
#          -0.04765532, -0.023988  , -0.00031032, -0.02245158,
#           0.0356696 , -0.01975085],
#         [ 0.01972734, -0.04935158, -0.02568839, -0.0477609 ,
#          -0.00703432, -0.01133585,  0.03427711, -0.03507178,
#           0.04701957, -0.03857826],
#         [-0.02715439, -0.00246812, -0.03468756, -0.01624999,
#           0.04305248, -0.04134461, -0.02315192, -0.03675082,
#           0.04884943,  0.03745064]],
#
#        [[ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.04898126,  0.00301876,  0.04093683, -0.03124532,
#           0.00100439,  0.01649359, -0.03797026,  0.04527355,
#           0.03773368, -0.00114442],
#         [ 0.01837954,  0.02516507, -0.04261074, -0.03787472,
#           0.01796364, -0.01875799, -0.00299148,  0.02235574,
#          -0.00868456,  0.02162528],
#         [ 0.00694495,  0.01096293,  0.02664652, -0.04566985,
#           0.00811823,  0.03059902,  0.04743042,  0.02783921,
#          -0.00504876, -0.00948261],
#         [-0.03714273,  0.03180916, -0.04790225,  0.01040291,
#          -0.04204428, -0.01961826, -0.04070854, -0.03623998,
#           0.03355278, -0.04887253],
#         [-0.02447709, -0.01647984, -0.03584441,  0.01272103,
#           0.04182531,  0.00438714, -0.04530661, -0.00569409,
#           0.01763486,  0.0427967 ]]], dtype=float32)
